# %% [raw]
# IMPORT PACKAGE

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %% [raw]
#  Loading data with Pandas
#
# We need to load transaction data  and behaviors segment into individual dataframes so that we can work with them in Python

# %%
df1 = pd.read_csv(r"C:\Users\SURFACE\Downloads\QVI_transaction_data.csv")
df2 = pd.read_csv(r"C:\Users\SURFACE\Downloads\QVI_purchase_behaviour.csv")

# %%
df1.head()
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  10/17/2018          1            1000       1         5
# 1   5/14/2019          1            1307     348        66
# 2   5/20/2019          1            1343     383        61
# 3   8/17/2018          2            2373     974        69
# 4   8/18/2018          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %%
df2.head()
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
#merge dataframe 
df = pd.merge(df1,df2,left_on ='LYLTY_CARD_NBR',right_on = 'LYLTY_CARD_NBR',how = 'left')

# %%
df
# Out:
#               DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       10/17/2018          1            1000       1         5
# 1        5/14/2019          1            1307     348        66
# 2        5/20/2019          1            1343     383        61
# 3        8/17/2018          2            2373     974        69
# 4        8/18/2018          2            2426    1038       108
# ...            ...        ...             ...     ...       ...
# 264831    3/9/2019        272          272319  270088        89
# 264832   8/13/2018        272          272358  270154        74
# 264833   11/6/2018        272          272379  270187        51
# 264834  12/27/2018        272          272379  270188        42
# 264835   9/22/2018        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %% [raw]
# Descriptive statistics of data
#
# Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   DATE              264836 non-null  object
#  1   STORE_NBR         264836 non-null  int64
#  2   LYLTY_CARD_NBR    264836 non-null  int64
#  3   TXN_ID            264836 non-null  int64
#  4   PROD_NBR          264836 non-null  int64
#  5   PROD_NAME         264836 non-null  object
#  6   PROD_QTY          264836 non-null  int64
#  7   TOT_SALES         264836 non-null  float64
#  8   LIFESTAGE         264836 non-null  object
#  9   PREMIUM_CUSTOMER  264836 non-null  object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 20.2+ MB

# %%
df
# Out:
#               DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       10/17/2018          1            1000       1         5
# 1        5/14/2019          1            1307     348        66
# 2        5/20/2019          1            1343     383        61
# 3        8/17/2018          2            2373     974        69
# 4        8/18/2018          2            2426    1038       108
# ...            ...        ...             ...     ...       ...
# 264831    3/9/2019        272          272319  270088        89
# 264832   8/13/2018        272          272358  270154        74
# 264833   11/6/2018        272          272379  270187        51
# 264834  12/27/2018        272          272379  270188        42
# 264835   9/22/2018        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
df.to_csv('data_store.csv')

# %%
# declaration of the 3 stores on trail
df4= pd.read_csv(r"C:\Users\SURFACE\Downloads\trail_stores_3.csv")
df4
# Out:
#       Customer_id       DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0              69  5/20/2019         88           88320   87811       113
# 1             202  6/17/2019         77           77069   74987        70
# 2            1438  3/28/2019         77           77000   74911        18
# 3            1439  4/13/2019         77           77000   74912        69
# 4            1440  7/17/2018         77         2330211  236744        94
# ...           ...        ...        ...             ...     ...       ...
# 3969       263916  7/22/2018         77           77238   75162        56
# 3970       263922  9/28/2018         77           77130   75055        83
# 3971       263924  9/18/2018         77           77099   75018        64
# 3972       263930  7/29/2018         77           77238   75163        13
# 3973       263934  11/7/2018         77           77021   74934        96
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# ...

# %%
# Total sales revenue for the 3 stores on trail
df4.groupby('STORE_NBR').agg({'TOT_SALES':'sum'})
# Out:
#            TOT_SALES
# STORE_NBR
# 77           3040.00
# 86          10635.35
# 88          16333.25

# %%
# Total number of Customers per store
df4.groupby('STORE_NBR')['Customer_id'].count()
# Out:
# STORE_NBR
# 77     563
# 86    1538
# 88    1873
# Name: Customer_id, dtype: int64

# %%
df4.corr(numeric_only=True)
# Out:
#                 Customer_id  STORE_NBR  LYLTY_CARD_NBR    TXN_ID  PROD_NBR  \
# Customer_id        1.000000  -0.120210        0.003084 -0.029511  0.020196
# STORE_NBR         -0.120210   1.000000       -0.096868  0.068102 -0.037424
# LYLTY_CARD_NBR     0.003084  -0.096868        1.000000  0.352331 -0.001837
# TXN_ID            -0.029511   0.068102        0.352331  1.000000  0.018749
# PROD_NBR           0.020196  -0.037424       -0.001837  0.018749  1.000000
# PROD_QTY          -0.038601   0.454343       -0.059109  0.025563 -0.027755
# TOT_SALES         -0.047948   0.433255       -0.012466  0.051484 -0.160192
#
#                 PROD_QTY  TOT_SALES
# Customer_id    -0.038601  -0.047948
# STORE_NBR       0.454343   0.433255
# LYLTY_CARD_NBR -0.059109  -0.012466
# TXN_ID          0.025563   0.051484
# PROD_NBR       -0.027755  -0.160192
# PROD_QTY        1.000000   0.514922
# TOT_SALES       0.514922   1.000000

# %%
sns.heatmap(df4.corr(numeric_only = True), 
                  annot = True,cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
df4
# Out:
#       Customer_id       DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0              69  5/20/2019         88           88320   87811       113
# 1             202  6/17/2019         77           77069   74987        70
# 2            1438  3/28/2019         77           77000   74911        18
# 3            1439  4/13/2019         77           77000   74912        69
# 4            1440  7/17/2018         77         2330211  236744        94
# ...           ...        ...        ...             ...     ...       ...
# 3969       263916  7/22/2018         77           77238   75162        56
# 3970       263922  9/28/2018         77           77130   75055        83
# 3971       263924  9/18/2018         77           77099   75018        64
# 3972       263930  7/29/2018         77           77238   75163        13
# 3973       263934  11/7/2018         77           77021   74934        96
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# ...

# %%
df4['TOTAL_REVENUE'] = df4['TOT_SALES'].groupby(df['STORE_NBR']).transform('sum')
df4
# Out:
#       Customer_id       DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0              69  5/20/2019         88           88320   87811       113
# 1             202  6/17/2019         77           77069   74987        70
# 2            1438  3/28/2019         77           77000   74911        18
# 3            1439  4/13/2019         77           77000   74912        69
# 4            1440  7/17/2018         77         2330211  236744        94
# ...           ...        ...        ...             ...     ...       ...
# 3969       263916  7/22/2018         77           77238   75162        56
# 3970       263922  9/28/2018         77           77130   75055        83
# 3971       263924  9/18/2018         77           77099   75018        64
# 3972       263930  7/29/2018         77           77238   75163        13
# 3973       263934  11/7/2018         77           77021   74934        96
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# ...

# %%
sns.kdeplot(df4,x='TOTAL_REVENUE',shade =True, hue =df4[ 'STORE_NBR']);

# %%
sns.histplot(df4,x='TOTAL_REVENUE', hue =df4['STORE_NBR']);

# %%
df4
# Out:
#       Customer_id       DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0              69  5/20/2019         88           88320   87811       113
# 1             202  6/17/2019         77           77069   74987        70
# 2            1438  3/28/2019         77           77000   74911        18
# 3            1439  4/13/2019         77           77000   74912        69
# 4            1440  7/17/2018         77         2330211  236744        94
# ...           ...        ...        ...             ...     ...       ...
# 3969       263916  7/22/2018         77           77238   75162        56
# 3970       263922  9/28/2018         77           77130   75055        83
# 3971       263924  9/18/2018         77           77099   75018        64
# 3972       263930  7/29/2018         77           77238   75163        13
# 3973       263934  11/7/2018         77           77021   74934        96
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# ...

# %%
#df4=df4.drop('Customer_id','DATE','LYLTY_CARD_NBR','TXN_ID','PROD_NBR','PROD_NAME',axis = 1,axis = 2,axis = 3,axis = 4,axis = 5,axis = 6)
sns.pairplot(df4,hue ='STORE_NBR')
